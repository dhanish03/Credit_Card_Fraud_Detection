# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanish03/Credit_Card_Fraud_Detection/blob/main/creditcardfraudetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
#load data set
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 37717  39076  1.117749 -1.544665 -0.145357 -1.307482 -1.392833 -0.630833
# 37718  39076  0.758729 -0.483875  0.125488  1.449159 -0.639231 -0.805011
# 37719  39076 -0.474907  0.835804  0.075878 -1.251283  2.492736  3.385419
# 37720  39077 -2.682780 -2.028562  1.745223 -1.157952 -0.143692 -0.807503
# 37721  39077  1.106292 -0.525727  0.926440  0.817696 -1.122177 -0.062703
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 37717 -0.563659 -0.038716 -2.173892  ... -0.334155 -1.108220  0.070461
# 37718  0.406994 -0.221212  0.068777  ...  0.210712  0.063091 -0.316636
# 37719  0.169507  0.934749 -0.584224  ... -0.270398 -0.866353 -0.085720
# 37720 -1.154141  0.436917 -0.293442  ...  0.353396  0.968145 -0.776459
# 37721       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37722 entries, 0 to 37721
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    37722 non-null  int64
#  1   V1      37722 non-null  float64
#  2   V2      37722 non-null  float64
#  3   V3      37722 non-null  float64
#  4   V4      37722 non-null  float64
#  5   V5      37722 non-null  float64
#  6   V6      37722 non-null  float64
#  7   V7      37721 non-null  float64
#  8   V8      37721 non-null  float64
#  9   V9      37721 non-null  float64
#  10  V10     37721 non-null  float64
#  11  V11     37721 non-null  float64
#  12  V12     37721 non-null  float64
#  13  V13     37721 non-null  float64
#  14  V14     37721 non-null  float64
#  15  V15     37721 non-null  float64
#  16  V16     37721 non-null  float64
#  17  V17     37721 non-null  float64
#  18  V18     37721 non-null  float64
#  19  V19     37721 non-null  float64
# ...

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    37618
# 1.0      103
# Name: count, dtype: int64

# %% [markdown]
# 0 --> Normal Transaction
# 1 --> Fraudulent Transaction

# %%
#separating data from analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (37618, 31)
# (103, 31)

# %%
#statistical measures of the data
legit.Amount.describe()
# Out:
# count    37618.000000
# mean        86.017411
# std        232.957939
# min          0.000000
# 25%          7.300000
# 50%         22.880000
# 75%         77.675000
# max       7879.420000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     103.000000
# mean       90.471165
# std       247.173335
# min         0.000000
# 25%         1.000000
# 50%         3.760000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
#compare values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    24778.212797 -0.186787  0.044196   0.749331  0.176750 -0.209569
# 1.0    20498.291262 -7.762676  5.838647 -10.957218  5.911555 -5.453798
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.105912 -0.092989  0.025693  0.243321  ...  0.044683 -0.032046
# 1.0   -2.306085 -7.743100  3.867920 -2.961800  ...  0.652319  0.628539
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.111604 -0.040404  0.007159  0.135739  0.021382  0.007030  0.003658
# 1.0   -0.354537 -0.362138 -0.234731  0.300023  0.180390  0.822304  0.102481
#
#           Amount
# Class
# 0.0    86.017411
# 1.0    90.471165
#
# [2 rows x 30 columns]

# %% [markdown]
# Under - Sampling

# %% [markdown]
# Build sample dataset containing similar distribution of normal transactions and fraudulent transactions.

# %% [markdown]
# Number of fraudulent transactions --> 103

# %%
legit_sample = legit.sample(n=103)

# %% [markdown]
# concatenating two dataframes

# %%
new_dataset = pd.concat([legit_sample,fraud],axis=0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 33287  37172  1.307400 -0.557251  0.403531 -0.597468 -1.012611 -0.830117
# 4266    3755  1.372955 -0.730758 -0.931581 -1.604395  1.443775  3.280036
# 31472  36381  1.135098 -1.422280  1.059353 -0.501487 -1.576462  0.788810
# 12988  22815  0.196935  1.977465 -1.796104  1.678595  1.119891 -1.197373
# 17024  28376 -1.617374 -0.069821  1.477316 -0.830521 -1.718512 -0.680189
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 33287 -0.497491 -0.147617 -0.849683  ...  0.318928  0.842961 -0.077433
# 4266  -1.150876  0.706540  0.358377  ... -0.269204 -0.906016  0.068290
# 31472 -1.485158  0.382476  0.374725  ...  0.222936  0.603012 -0.279977
# 12988  0.683799 -0.082904  1.021657  ... -0.268007 -0.116640  0.201285
# 17024 -0.678319  0.171298  0.195828  ... -0.221856  0.515223  0.090304
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 30442  35926 -3.896583  4.518355 -4.454027  5.547453 -4.121459 -1.163407
# 30473  35942 -4.194074  4.382897 -5.118363  4.455230 -4.812621 -1.224645
# 30496  35953 -4.844372  5.649439 -6.730396  5.252842 -4.409566 -1.740767
# 31002  36170 -5.685013  5.776516 -7.064977  5.902715 -4.715564 -1.755633
# 33276  37167 -7.923891 -5.198360 -3.000024  4.420666  2.272194 -3.394483
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 30442 -6.805053  2.928356 -4.917130  ...  1.691042  0.920021 -0.151104
# 30473 -7.281328  3.332250 -3.679659  ...  1.550473  0.614573  0.028521
# 30496 -6.311699  3.449167 -5.416284  ...  1.194888 -0.845753  0.190674
# 31002 -6.958679  3.877795 -5.541529  ...  1.128641 -0.962960 -0.110045
# 33276 -5.283435  0.131619  0.658176  ... -0.734308 -0.599926 -4.908301
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    103
# 1.0    103
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    22723.601942 -0.187790 -0.021728   0.569876  0.034937 -0.243983
# 1.0    20498.291262 -7.762676  5.838647 -10.957218  5.911555 -5.453798
#
#              V6        V7       V8        V9  ...       V20       V21  \
# Class                                         ...
# 0.0   -0.067600 -0.199343  0.05622  0.288712  ...  0.025744 -0.048553
# 1.0   -2.306085 -7.743100  3.86792 -2.961800  ...  0.652319  0.628539
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.108536 -0.037392  0.051054  0.175615  0.014245  0.049793  0.034324
# 1.0   -0.354537 -0.362138 -0.234731  0.300023  0.180390  0.822304  0.102481
#
#           Amount
# Class
# 0.0    83.074175
# 1.0    90.471165
#
# [2 rows x 30 columns]

# %% [markdown]
# splitting data into features and target

# %%
X = new_dataset.drop(columns='Class',axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 33287  37172  1.307400 -0.557251  0.403531 -0.597468 -1.012611 -0.830117
# 4266    3755  1.372955 -0.730758 -0.931581 -1.604395  1.443775  3.280036
# 31472  36381  1.135098 -1.422280  1.059353 -0.501487 -1.576462  0.788810
# 12988  22815  0.196935  1.977465 -1.796104  1.678595  1.119891 -1.197373
# 17024  28376 -1.617374 -0.069821  1.477316 -0.830521 -1.718512 -0.680189
# ...      ...       ...       ...       ...       ...       ...       ...
# 30442  35926 -3.896583  4.518355 -4.454027  5.547453 -4.121459 -1.163407
# 30473  35942 -4.194074  4.382897 -5.118363  4.455230 -4.812621 -1.224645
# 30496  35953 -4.844372  5.649439 -6.730396  5.252842 -4.409566 -1.740767
# 31002  36170 -5.685013  5.776516 -7.064977  5.902715 -4.715564 -1.755633
# 33276  37167 -7.923891 -5.198360 -3.000024  4.420666  2.272194 -3.394483
#
#              V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
print(Y)
# Out:
# 33287    0.0
# 4266     0.0
# 31472    0.0
# 12988    0.0
# 17024    0.0
#         ...
# 30442    1.0
# 30473    1.0
# 30496    1.0
# 31002    1.0
# 33276    1.0
# Name: Class, Length: 206, dtype: float64

# %% [markdown]
# split data into training data and testing data

# %%
X_train, X_test, Y_train, Y_test =train_test_split(X, Y, test_size=0.2,stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (206, 30) (164, 30) (42, 30)

# %% [markdown]
# logistic regression

# %%
model = LogisticRegression()

# %% [markdown]
# Accuracy Score

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on training data',training_data_accuracy)
# Out:
# Accuracy on training data 0.9817073170731707

# %%
#accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test )

# %%
print('Accuracy score on data', test_data_accuracy)
# Out:
# Accuracy score on data 0.9523809523809523
